# %%
from ryPat import *

# %%
ryGradient_demo()
# Out:
# x⋅(x - 10)⋅(x + 10) + y⋅(y - 10)⋅(y + 10)
# x⋅(x - 10) + x⋅(x + 10) + (x - 10)⋅(x + 10)
# y⋅(y - 10) + y⋅(y + 10) + (y - 10)⋅(y + 10)
# x*(x - 10)*(x + 10) + y*(y - 10)*(y + 10)
# x*(x - 10) + x*(x + 10) + (x - 10)*(x + 10)
# y*(y - 10) + y*(y + 10) + (y - 10)*(y + 10)

# %%
# %matplotlib qt

# %%
ryGradient_demo()
# Out:
# x⋅(x - 10)⋅(x + 10) + y⋅(y - 10)⋅(y + 10)
# x⋅(x - 10) + x⋅(x + 10) + (x - 10)⋅(x + 10)
# y⋅(y - 10) + y⋅(y + 10) + (y - 10)⋅(y + 10)
# x*(x - 10)*(x + 10) + y*(y - 10)*(y + 10)
# x*(x - 10) + x*(x + 10) + (x - 10)*(x + 10)
# y*(y - 10) + y*(y + 10) + (y - 10)*(y + 10)
