# %%
from ryPat import *

# %%
sampSize= 1000
nBins= 20

#X=   np.random.random(size= sampSize)
X= np.random.standard_normal(sampSize)
X= np.random.binomial(n= 10, p=.5, size= sampSize)
X= np.random.poisson(lam=5, size= sampSize)
X= np.random.uniform(low= 10, high=20, size= sampSize)

t= np.arange(len(X))

fg, ax= pl.subplots(2,1)
ax[0].scatter(X,t)
#ax[1].hist(X, bins= nBins)

f, x= np.histogram(X, bins= nBins)
ax[1].stem(x[:-1], f,'r--')
X[:20], f, x
# Out:
# (array([10.02430652, 11.10679681, 17.55247432, 16.87883414, 19.50398402,
#         10.18626082, 13.75011343, 19.19606375, 18.01528396, 15.09239734,
#         12.16778832, 17.93480271, 19.56486646, 18.16966112, 17.66567894,
#         16.76551139, 15.52398163, 12.3470816 , 18.77693439, 10.31522573]),
#  array([60, 32, 56, 52, 54, 43, 49, 44, 61, 54, 35, 52, 52, 50, 56, 63, 40,
#         38, 59, 50], dtype=int64),
#  array([10.00901063, 10.50854072, 11.0080708 , 11.50760089, 12.00713097,
#         12.50666106, 13.00619114, 13.50572123, 14.00525131, 14.50478139,
#         15.00431148, 15.50384156, 16.00337165, 16.50290173, 17.00243182,
#         17.5019619 , 18.00149199, 18.50102207, 19.00055216, 19.50008224,
#         19.99961233]))

# %%
# show using seaborn

import seaborn as sns
#sns.set()
sns.distplot(X, bins= nBins)
# Out:
# M:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
# fit to Gaussian should improve with larger N. increase N in a loop and extract pdensity

ns = np.arange(50,10000,100)
nbins = 100 #50

allhist = np.zeros((len(ns),nbins))

for i in range(len(ns)):
    sig1 = np.sin(np.linspace(0,6*np.pi,ns[i]))
    sig2 = np.random.rand(ns[i])*2-1
    
    [allhist[i,:],binedges] = np.histogram(sig1+sig2,nbins,density=True)

plt.pcolor(binedges[0:-1],ns,allhist,vmax=.6,cmap='rainbow') #'Purples') # viridis
plt.xlabel('Data value')
plt.ylabel('Points in sample')
plt.gca().invert_xaxis()
plt.colorbar()
plt.show()
# Out:
# <ipython-input-65-f52bfca7dea9>:14: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(binedges[0:-1],ns,allhist,vmax=.6,cmap='rainbow') #'Purples') # viridis

# %%
import ..ryDsp2021.ryDsp2021.ryDsp
# Out:
#   File "<ipython-input-67-e602d8081dd7>", line 1
#     import ..ryDsp2021.ryDsp2021.ryDsp
#            ^
# SyntaxError: invalid syntax

# %%
import sys
sys.path.insert(0,'L:\\OneDrive - 長庚大學\\_ry_2021_fall_CguOneDrive\\_ryDsp2021\\ryDsp2021')

# %%
from ryDsp import *

# %%
x= getWavFromYoutube()
# Out:
# url= https://youtu.be/HBUwoAoScaQ, info= 手嶌 葵《テルーの唄 》中日字幕

# %%
sr, wav= x
#ryDsp.playWav_jpt(wav[::-1,:])

# %%
#ryDsp.playWav(wav[::-1,:])

# %%
X= wav.copy()
#np.random.shuffle(X)
playWav(X)
# Out:
# playWav, sr= 44100, duration= 259.065 sec

# %%
x0= X[::1000,0]
x1= X[::1000,1]
pl.hist2d(x0,x1, bins=100, vmax=10, cmap='rainbow')
pl.colorbar()

# %%
fg,ax= pl.subplots(2,1)
_= ax[0].hist(x0, bins=100)
_= ax[1].hist(x1, bins=100)
#pl.colorbar()

# %%
import seaborn as sb

sb.jointplot(
    x0,
    x1,
    kind=  'scatter',
    color= [.5,0,1]
).plot_joint(sb.kdeplot)
# Out:
# M:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import yfinance as yf

# %%
googl= yf.Ticker('GOOGL')
aapl=  yf.Ticker('AAPL')
spy=   yf.Ticker('SPY')

# %%
X= aapl.history(period='1y')
X= X['Close']

Y= googl.history(period='1y')
Y= Y['Close']

# %%
X.hist()
# Out:
# <AxesSubplot:>

# %%
Y.hist()
# Out:
# <AxesSubplot:>

# %%
X.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
Y.plot(kind='density')
#X.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
pl.stem(X)
# Out:
# <StemContainer object of 3 artists>

# %%
pl.stem(Y)
# Out:
# <StemContainer object of 3 artists>

# %%
import pandas as pd
pd.plotting.boxplot(Y)
# Out:
# <AxesSubplot:>

# %%
X.diff()
# Out:
# Date
# 2020-10-30         NaN
# 2020-11-02   -0.089432
# 2020-11-03    1.659332
# 2020-11-04    4.481171
# 2020-11-05    4.053932
#                 ...
# 2021-10-25   -0.050003
# 2021-10-26    0.680008
# 2021-10-27   -0.470001
# 2021-10-28    3.720001
# 2021-10-29   -2.770004
# Name: Close, Length: 252, dtype: float64

# %%
X.cumsum()
# Out:
# Date
# 2020-10-30      108.164307
# 2020-11-02      216.239182
# 2020-11-03      325.973389
# 2020-11-04      440.188766
# 2020-11-05      558.458076
#                   ...
# 2021-10-25    33038.776772
# 2021-10-26    33188.096779
# 2021-10-27    33336.946785
# 2021-10-28    33489.516792
# 2021-10-29    33639.316795
# Name: Close, Length: 252, dtype: float64

# %%
X.to_list()
X.to_numpy()
# Out:
# array([108.16430664, 108.07487488, 109.73420715, 114.21537781,
#        118.26931   , 118.13494873, 115.77603149, 115.42766571,
#        118.93119812, 118.65251923, 118.70228577, 119.73741913,
#        118.83167267, 117.47803497, 118.08517456, 116.79125977,
#        113.31758118, 114.63140869, 115.48738098, 116.04476166,
#        118.49326324, 122.14610291, 122.50442505, 122.36507416,
#        121.67829895, 123.17128754, 123.79833984, 121.210495  ,
#        122.66366577, 121.83755493, 121.210495  , 127.28196716,
#        127.21229553, 128.09812927, 126.06768036, 127.63033295,
#        131.26325989, 130.34757996, 131.35282898, 136.05076599,
#        134.23927307, 133.09465027, 132.06947327, 128.80482483,
#        130.39732361, 126.00795746, 130.30775452, 131.4324646 ,
#        128.37683105, 128.19767761, 130.27789307, 128.30715942,
#        126.54542542, 127.23220825, 131.41256714, 136.22993469,
#        138.41964722, 142.25161743, 142.49052429, 141.39564514,
# ...

# %%
import scipy as st

# %%
def f(x):
    y= x**2
    return y

st.integrate.quad(f, 0, 10)
# Out:
# (333.33333333333326, 3.700743415417188e-12)

# %%
y= np.linspace(-3,3,11)
y*(y>=0)
# Out:
# array([-0. , -0. , -0. , -0. , -0. ,  0. ,  0.6,  1.2,  1.8,  2.4,  3. ])

# %%
# 數值積分
#
# ref: https://docs.scipy.org/doc/scipy/reference/integrate.html
#
def f(x):
    #y= x**2          # 這種函數是還好，
    y= (1-x**2)**.5 # 但像這種函數就誤差很大
    
    y= (1-x**2)     # 除非改成這樣，怪怪的函數就要怪怪的寫法！
    y= (y*(y>=0))**.5
    
    return y

dx= 1e-5 # dx 不能太大，也不能太小，就是這裡很麻煩！！
x= np.arange(-3, +3, dx)

# or
'''
N= 100000
dx= 1/N
x= np.linspace(10,20, N)
'''
y=     f(x)
y0=  np.cumsum(f(x))*dx

y1=  np.diff(f(x))  /dx
y1=  np.insert(y1,0,y1[0])

pl.plot(x,y,'r',
        x,y0,'g',
        #x,y1,'b'
       )

pl.legend(['y',
           'y0, integral',
           #'y1, diff'
          ]
         )
# Out:
# <ipython-input-190-d47c1842f82f>:7: RuntimeWarning: invalid value encountered in sqrt
#   y= (1-x**2)**.5 # 但像這種函數就誤差很大

# %%
st.integrate.simpson?
# Out:
# Signature: st.integrate.simpson(y, x=None, dx=1, axis=-1, even='avg')
# Docstring:
# Integrate y(x) using samples along the given axis and the composite
# Simpson's rule. If x is None, spacing of dx is assumed.
#
# If there are an even number of samples, N, then there are an odd
# number of intervals (N-1), but Simpson's rule requires an even number
# of intervals. The parameter 'even' controls how this is handled.
#
# Parameters
# ----------
# y : array_like
#     Array to be integrated.
# x : array_like, optional
#     If given, the points at which `y` is sampled.
# dx : int, optional
#     Spacing of integration points along axis of `x`. Only used when
#     `x` is None. Default is 1.
# axis : int, optional
#     Axis along which to integrate. Default is the last axis.
# even : str {'avg', 'first', 'last'}, optional
#     'avg' : Average two results:1) use the first N-2 intervals with
#               a trapezoidal rule on the last interval and 2) use the last
# ...

# %%
np.random.permutation([0,1,2,3])
# Out:
# array([3, 0, 1, 2])

# %%
import sympy as sm

# %%
def f(α):
    y= sm.integrate(x**(α-1)*sm.exp(-x), (x, 0,sm.oo))
    return y
f(1)
# Out:
# ------------------------------------------------------
# ValueError           Traceback (most recent call last)
# <ipython-input-348-f3f89e6eebe9> in <module>
#       2     y= sm.integrate(x**(α-1)*sm.exp(-x), (x, 0,sm.oo))
#       3     return y
# ----> 4 f(1)
#
# <ipython-input-348-f3f89e6eebe9> in f(α)
#       1 def f(α):
# ----> 2     y= sm.integrate(x**(α-1)*sm.exp(-x), (x, 0,sm.oo))
#       3     return y
#       4 f(1)
#
# M:\ProgramData\Anaconda3\lib\site-packages\sympy\integrals\integrals.py in integrate(meijerg, conds, risch, heurisch, manual, *args, **kwargs)
#    1566         'manual': manual
#    1567         }
# -> 1568     integral = Integral(*args, **kwargs)
#    1569
#    1570     if isinstance(integral, Integral):
#
# M:\ProgramData\Anaconda3\lib\site-packages\sympy\integrals\integrals.py in __new__(cls, function, *symbols, **assumptions)
#      89                 useinstead="the as_expr or integrate methods of Poly").warn()
#      90
# ...
