# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt

from ryPat import *

# %%
# parameters
n = 100
a = 1
h = 1
k = -2

# x-axis points to evaluate the function
x = np.linspace(-2,4,n)

# create the function
y = a*(x-h)**2 + k

# and plot it!
plt.plot(x,y)
plt.grid(True)
plt.axis('square')
plt.show()

# %%
x= sm.symbols('x')
f= sm.sin(x**2)
F= sm.Integral(f,(x,0,x))
F
# Out:
# Integral(sin(x**2), (x, 0, x))

# %%
F= F.doit()
F
# Out:
# 3*sqrt(2)*sqrt(pi)*fresnels(sqrt(2)*x/sqrt(pi))*gamma(3/4)/(8*gamma(7/4))

# %%
sm.plotting.plot(f, (x,0,10))

# %%
sm.plotting.plot(F, (x,0,10))
