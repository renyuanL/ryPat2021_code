# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Oct  4 14:06:17 2021
@author: Teo Bee Guan
"""

import requests
from bs4 import BeautifulSoup 
import pandas as pd
from IPython.display import display, HTML

ticker= "GOOGL" #"AAPL"
url=    f"https://financialmodelingprep.com/financial-summary/{ticker}"
request= requests.get(url)

print(f'url= {url}')
#print(request.text)

display(HTML(request.text))
# Out:
# url= https://financialmodelingprep.com/financial-summary/GOOGL
# ...

# %%
parser= BeautifulSoup(request.text, "html.parser")
news_html= parser.find_all('a', {'class': 'article-item'})
print(news_html[0])
#display(HTML(news_html[-1]))
# Out:
# <a class="article-item" href="https://www.pymnts.com/news/investment-tracker/2021/google-invests-in-robot-delivery-company-nuro/" rel="noopener" target="_blank"><div class="articles__img"><img alt="Google Invests in Robot Delivery Company Nuro" src="https://cdn.snapi.dev/images/v1/n/u/nuro-google-funding-457x274-1082762.jpg"/></div> <div class="article-rightside"><h4 class="article-title">Google Invests in Robot Delivery Company Nuro</h4> <h5 class="article-date">2021-11-02 15:35</h5> <p class="article-text">Google was a surprise investor in autonomous driving platform Nuro during a recent $600 million Series D fundraising round that will help the company ...</p></div> <div class="article-source"><svg fill="none" height="15" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="3" viewbox="0 0 24 24" width="15" xmlns="http://www.w3.org/2000/svg"><path d="M10 13a5 5 0 0 0 7.54.54l3-3a5 5 0 0 0-7.07-7.07l-1.72 1.71"></path><path d="M14 11a5 5 0 0 0-7.54-.54
# ...

# %% [markdown]
# <a class="article-item" href="https://www.pymnts.com/news/investment-tracker/2021/google-invests-in-robot-delivery-company-nuro/" rel="noopener" target="_blank"><div class="articles__img"><img alt="Google Invests in Robot Delivery Company Nuro" src="https://cdn.snapi.dev/images/v1/n/u/nuro-google-funding-457x274-1082762.jpg"/></div> <div class="article-rightside"><h4 class="article-title">Google Invests in Robot Delivery Company Nuro</h4> <h5 class="article-date">2021-11-02 15:35</h5> <p class="article-text">Google was a surprise investor in autonomous driving platform Nuro during a recent $600 million Series D fundraising round that will help the company ...</p></div> <div class="article-source"><svg fill="none" height="15" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="3" viewbox="0 0 24 24" width="15" xmlns="http://www.w3.org/2000/svg"><path d="M10 13a5 5 0 0 0 7.54.54l3-3a5 5 0 0 0-7.07-7.07l-1.72 1.71"></path><path d="M14 11a5 5 0 0 0-7.54-.54l-3 3a5 5 0 0 0 7.07 7.07l1.71-1.71"></path></svg> <h5>PYMNTS</h5></div></a>

# %%
sentiments = []
for i in range(0, len(news_html)):
    sentiments.append(
            {
                'ticker': ticker,
                'date': news_html[i].find('h5', {'class': 'article-date'}).text,
                'title': news_html[i].find('h4', {'class': 'article-title'}).text,
                'text': news_html[i].find('p', {'class': 'article-text'}).text
            }
        )

df= pd.DataFrame(sentiments)
df= df.set_index('date')
df
# Out:
#                  ticker                                              title  \
# date
# 2021-11-02 15:35  GOOGL      Google Invests in Robot Delivery Company Nuro
# 2021-11-02 14:22  GOOGL  Italian watchdog drops Google display adv case...
# 2021-11-02 13:23  GOOGL  Here's why Jim Lebenthal sold some Microsoft a...
# 2021-11-02 11:35  GOOGL  Spain adopts EU copyright law, paving way for ...
# 2021-11-02 11:14  GOOGL  Digital Currency Group Sells $700M Shares To A...
# 2021-11-02 09:48  GOOGL  These 2 Charts Remind You Alphabet Is Still a ...
# 2021-11-02 09:42  GOOGL  Former Google CEO sounds skeptical that Facebo...
# 2021-11-01 16:47  GOOGL  CoinDesk owner wins SoftBank and Alphabet as i...
# 2021-11-01 14:56  GOOGL      Digging into Google's push to freeze ePrivacy
# 2021-11-01 13:49  GOOGL  Surging Earnings Estimates Signal Upside for A...
#
#                                                                text
# date
# ...
